# %%
# 나의 코드
N = int(input())

for i in range(1, N+1):
    print('*' * ((N - i) + 1))
# Out:
# *****
# ****
# ***
# **
# *

# %%
# 추천 코드
N = int(input())

for i in range(N, 0, -1):
    print('*' * i)
# Out:
# *****
# ****
# ***
# **
# *
